# %%
import pandas as pd
import numpy as np
import requests
import ScraperFC

# %%
fbref = ScraperFC.FBRef()
under = ScraperFC.Understat()
fte = ScraperFC.FiveThirtyEight()
# Out:
# [WDM] - Downloading: 100%|█████████████████| 8.04M/8.04M [00:00<00:00, 14.1MB/s]

# %%
fte.scrape_matches(2019,'EPL')
# Out:
#     season        date  league_id                   league  \
# 0     2019  2018-08-10       2411  Barclays Premier League
# 1     2019  2018-08-11       2411  Barclays Premier League
# 2     2019  2018-08-11       2411  Barclays Premier League
# 3     2019  2018-08-11       2411  Barclays Premier League
# 4     2019  2018-08-11       2411  Barclays Premier League
# ..     ...         ...        ...                      ...
# 375   2019  2019-05-12       2411  Barclays Premier League
# 376   2019  2019-05-12       2411  Barclays Premier League
# 377   2019  2019-05-12       2411  Barclays Premier League
# 378   2019  2019-05-12       2411  Barclays Premier League
# 379   2019  2019-05-12       2411  Barclays Premier League
#
#                         team1              team2   spi1   spi2   prob1  \
# 0           Manchester United     Leicester City  82.66  69.64  0.6400
# 1                   Newcastle  Tottenham Hotspur  67.21  85.75  0.2010
# 2                      Fulham     Crystal Palace  64.41  70.20  0.3881
# 3             AFC Bournemouth       Cardiff City  62.75  59.47  0.4886
# 4           Huddersfield Town            Chelsea  60.20  84.39  0.1644
# ..                        ...                ...    ...    ...     ...
# 375  Brighton and Hove Albion    Manchester City  58.23  94.24  0.0346
# 376                 Liverpool      Wolverhampton  93.31  72.23  0.8453
# 377               Southampton  Huddersfield Town  66.77  50.81  0.4893
# 378         Manchester United       Cardiff City  76.84  58.35  0.5125
# 379         Tottenham Hotspur            Everton  83.51  76.69  0.4852
#
#       prob2  ...  importance1  importance2  score1  score2   xg1   xg2  nsxg1  \
# 0    0.1385  ...         60.3         21.3     2.0     1.0  1.50  1.72   0.71
# 1    0.5565  ...         23.8         57.8     1.0     2.0  1.08  2.15   1.60
# 2    0.3341  ...         31.9         18.1     0.0     2.0  0.60  0.89   1.38
# 3    0.2451  ...         36.3         40.0     2.0     0.0  2.20  0.96   2.28
# 4    0.5945  ...         36.1         58.8     0.0     3.0  0.45  2.16   0.94
# ..      ...  ...          ...          ...     ...     ...   ...   ...    ...
# 375  0.8527  ...          0.0        100.0     1.0     4.0  0.67  2.11   0.33
# 376  0.0351  ...         58.9          0.0     2.0     0.0  2.00  1.09   1.18
# 377  0.2390  ...          0.0          0.0     1.0     1.0  0.96  1.02   1.38
# 378  0.2351  ...          0.0          0.0     0.0     2.0  1.95  1.66   3.17
# 379  0.2388  ...          0.8          0.0     2.0     2.0  0.86  2.43   0.84
#
#      nsxg2  adj_score1  adj_score2
# 0     1.80        1.78        1.05
# 1     1.50        1.05        2.10
# 2     1.22        0.00        1.86
# 3     1.16        1.58        0.00
# 4     1.35        0.00        2.90
# ..     ...         ...         ...
# 375   3.74        1.05        4.16
# 376   1.12        1.82        0.00
# 377   0.48        1.05        1.05
# 378   0.63        0.00        2.10
# 379   1.34        2.10        2.10
#
# [380 rows x 23 columns]

# %%
seasons = [2021]

# %%
for season in seasons:

    underMatches = under.scrape_matches(season+1,'EPL')
    underMatches.to_csv('/Users/moksh/PL Predictions/UnderStatDfs/UnderStat{year}Season.csv'.format(year=season))
# Out:
# 100%|█████████████████████████████████████████| 380/380 [16:58<00:00,  2.68s/it]
